# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import seaborn as sns

DQN_avg =  np.loadtxt("DQN_avg_reward.txt", delimiter=',')
DQN_total_reward =  np.loadtxt("DQN_Total_reward.txt", delimiter=',')
DQN = DQN_total_reward.mean()

DDQN_avg =  np.loadtxt("DDQN_avg_reward.txt", delimiter=',')
DDQN_total_reward =  np.loadtxt("DDQN_Total_reward.txt", delimiter=',')
DDQN = DDQN_total_reward.mean()

D3QN_avg =  np.loadtxt("avg_reward_D3QN.txt", delimiter=',')
D3QN_total_reward =  np.loadtxt("Total_reward_D3QN.txt", delimiter=',')
D3QN = D3QN_total_reward.mean()

# %%
print('DQN_avg : ',DQN_avg)
print('DQN_total_reward : ',DQN_total_reward)
print('DDQN_avg : ',DDQN_avg)
print('DDQN_total_reward : ',DDQN_total_reward)
print('D3QN_avg : ',D3QN_avg)
print('D3QN_total_reward : ',D3QN_total_reward)
# Out:
# DQN_avg :  [0.         1.33333333 0.96091348 ... 3.14456697 3.14454402 3.14454604]
# DQN_total_reward :  [ 0.          4.          1.7654809  ... 45.21212121  0.
#  16.        ]
# DDQN_avg :  [2.95991778 3.05995204 2.82457111 ... 3.15019631 3.15024091 3.15023052]
# DDQN_total_reward :  [20.71942446 16.          0.         ... 70.42424242 69.21212121
#  20.60606061]
# D3QN_avg :  [0.         0.44890401 0.98262194 ... 3.15008738 3.15009567 3.15005453]
# D3QN_total_reward :  [  0.           1.79561605   6.06535948 ...  67.63636364 120.84848485
#   25.81818182]

# %%
plt.figure()
plt.title("DQN Average reward")
plt.grid(True)

plt.xlabel("Episode")
plt.xlim(0,10000)

plt.ylabel("DQN Average reward")
plt.ylim(0, 4)

plt.plot(DQN_avg, "r-", linewidth=2.0, label="DQN Average reward")

plt.legend(loc="best", shadow=True)
plt.savefig('DQN Average reward.png')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-64df8535fa4f> in <module>
#      11 # plt.plot(DQN_avg, "r-", linewidth=2.0, label="DQN Average reward")
#      12 for i in range(len(DQN_avg)):
# ---> 13     sns.tsplot(time=i, data=DQN_avg[i], color='r', linestyle='-', condition='DQN Average reward.png')
#      14 #plt.legend(loc="best", shadow=True)
#      15 #plt.savefig('DQN Average reward.png')
#
# ~/anaconda3/envs/RL/lib/python3.7/site-packages/seaborn/timeseries.py in tsplot(data, time, unit, condition, value, err_style, ci, interpolate, color, estimator, n_boot, err_palette, err_kws, legend, ax, **kwargs)
#     216         elif data.ndim == 2:
#     217             data = data[:, :, np.newaxis]
# --> 218         n_unit, n_time, n_cond = data.shape
#     219
#     220         # Units are experimental observations. Maybe subjects, or neurons
#
# ...

# %%
plt.figure()
plt.title("DDQN Average reward")
plt.grid(True)

plt.xlabel("Episode")
plt.xlim(0,10000)

plt.ylabel("DDQN Average reward")
plt.ylim(0, 4)

plt.plot(DDQN_avg, "b-", linewidth=2.0, label="DDQN Average reward")

plt.legend(loc="best", shadow=True)

plt.savefig('DDQN Average reward.png')


plt.show()

# %%
plt.figure()
plt.title("D3QN Average reward")
plt.grid(True)

plt.xlabel("Episode")
plt.xlim(0,10000)

plt.ylabel("D3QN Average reward")
plt.ylim(0, 4)

plt.plot(D3QN_avg, "g-", linewidth=2.0, label="D3QN Average reward")

plt.legend(loc="best", shadow=True)

plt.savefig('D3QN Average reward.png')


plt.show()

# %%
x = np.linspace(0, 10000)
y1 = x *0 + DQN
y2 = x *0 + DDQN
y3 = x *0 + D3QN

plt.figure()
plt.title("DQN_total_reward")
plt.grid(True)

plt.xlabel("Episode")
plt.xlim(0,10000)

plt.ylabel("DQN_total_reward")
plt.ylim(0, 500)

plt.plot(DQN_total_reward, "b-", linewidth=2.0, label="DQN_total_reward")
plt.plot(x,y1, "k--", linewidth=2.0, label="DQN")

plt.legend(loc="best", shadow=True)

plt.savefig('DQN_total_reward.png')

plt.show()

# %%
x = np.linspace(0, 10000)
y1 = x *0 + DQN
y2 = x *0 + DDQN
y3 = x *0 + D3QN

plt.figure()
plt.title("DDQN_total_reward")
plt.grid(True)

plt.xlabel("Episode")
plt.xlim(0,10000)

plt.ylabel("DDQN_total_reward")
plt.ylim(0, 500)

plt.plot(DDQN_total_reward, "b-", linewidth=2.0, label="DDQN_total_reward")
plt.plot(x,y2, "c--", linewidth=2.0, label="DDQN")

plt.legend(loc="best", shadow=True)

plt.savefig('DDQN_total_reward.png')



plt.show()

# %%
x = np.linspace(0, 10000)
y1 = x *0 + DQN
y2 = x *0 + DDQN
y3 = x *0 + D3QN

plt.figure()
plt.title("D3QN_total_reward")
plt.grid(True)

plt.xlabel("Episode")
plt.xlim(0,10000)

plt.ylabel("D3QN_total_reward")
plt.ylim(0, 500)

plt.plot(D3QN_total_reward, "b-", linewidth=2.0, label="D3QN_total_reward")
plt.plot(x,y3, "m--", linewidth=2.0, label="D3QN")

plt.legend(loc="best", shadow=True)
plt.savefig('D3QN_total_reward.png')


plt.show()

# %%
x = np.linspace(0, 10000)
y1 = x *0 + DQN
y2 = x *0 + DDQN
y3 = x *0 + D3QN

plt.figure(figsize=(22,10))
plt.title("total_reward")
plt.grid(True)

plt.xlabel("Episode")
plt.xlim(0,10000)

plt.ylabel("total_reward")
plt.ylim(0, 500)

plt.plot(D3QN_total_reward, "r-", linewidth=2.0, label="D3QN_total_reward")
plt.plot(DDQN_total_reward, "b-", linewidth=2.0, label="DDQN_total_reward")
plt.plot(DQN_total_reward, "g-", linewidth=2.0, label="DQN_total_reward")

plt.plot(x,y1, "k--", linewidth=2.0, label="DQN")
plt.plot(x,y2, "c--", linewidth=2.0, label="DDQN")
plt.plot(x,y3, "m--", linewidth=2.0, label="D3QN")


plt.legend(loc="best", shadow=True)

plt.savefig('Compare_total_reward.png')


plt.show()

# %%
plt.figure(figsize=(22,10))
plt.title("Average reward")
plt.grid(True)

plt.xlabel("Episode")
plt.xlim(0,10000)

plt.ylabel("Average reward")
plt.ylim(0, 4)

plt.plot(D3QN_avg, "r-", linewidth=2.0, label="D3QN Average reward")
plt.plot(DDQN_avg, "b-", linewidth=2.0, label="DDQN Average reward")
plt.plot(DQN_avg, "g-", linewidth=2.0, label="DQN Average reward")

plt.legend(loc="best", shadow=True)

plt.savefig('Compare_average_reward.png')


plt.show()

# %%
fig = plt.figure(figsize=(22,10))
x_data = []
[x_data.append(i) for i in range(10000)]
sns.tsplot(time=x_data, data=DQN_avg, color='r', linestyle='-', condition='algo1')
sns.tsplot(time=x_data, data=DDQN_avg, color='b', linestyle='-', condition='algo2')
plt.show()
